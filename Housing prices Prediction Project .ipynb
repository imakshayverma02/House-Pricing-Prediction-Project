# %% [markdown]
# #  TeamName : Technerds(Akshay Verma & Rashi)

# %% [markdown]
# # House Price Prediction
#
# #### Description : This is a notebook for visualization of various features which states the sales price of houses. Then data is taken from the "EdgeFX Technologies Hackathon" challenge.

# %% [markdown]
# ## Step1 :- Importing and Understanding Data

# %%
# IMPORTING PANDAS LIBRARY
import pandas as pd

# %%
# Importing Housing.csv
Housing_multi = pd.read_csv('Housing.csv')

# %%
#first 30 observations 
Housing_multi.head(30)
# Out:
#        price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0   13300000   7420         4          2        3      yes        no       no
# 1   12250000   8960         4          4        4      yes        no       no
# 2   12250000   9960         3          2        2      yes        no      yes
# 3   12215000   7500         4          2        2      yes        no      yes
# 4   11410000   7420         4          1        2      yes       yes      yes
# 5   10850000   7500         3          3        1      yes        no      yes
# 6   10150000   8580         4          3        4      yes        no       no
# 7   10150000  16200         5          3        2      yes        no       no
# 8    9870000   8100         4          1        2      yes       yes      yes
# 9    9800000   5750         3          2        4      yes       yes       no
# 10   9800000  13200         3          1        2      yes        no      yes
# ...

# %%
#Looking at the last 5 rows 
Housing_multi.tail()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished

# %%
# What type of Values are stored i the columns ?
Housing_multi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
# price               545 non-null int64
# area                545 non-null int64
# bedrooms            545 non-null int64
# bathrooms           545 non-null int64
# stories             545 non-null int64
# mainroad            545 non-null object
# guestroom           545 non-null object
# basement            545 non-null object
# hotwaterheating     545 non-null object
# airconditioning     545 non-null object
# parking             545 non-null int64
# prefarea            545 non-null object
# furnishingstatus    545 non-null object
# dtypes: int64(6), object(7)
# memory usage: 55.4+ KB

# %%
# Let's look at some statistical information about our dataframe.
Housing_multi.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %% [markdown]
# ## Step2 :- Visualising Data

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# using seaborn to find the relation between the different features given
# Let's plot a pair plot of all variables in our dataframe
sns.pairplot(Housing_multi)

# %%
# Visualise the relationship between the features and the response using scatterplots
sns.pairplot(Housing_multi, x_vars = ['price','area','bedrooms','bathrooms','stories'], y_vars='parking', size=7,aspect=0.7,kind='scatter')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Step3 :- Splitting the Data for Training and Testing

# %%
# Putting feature variable to X
X= Housing_multi[['price','area','bedrooms','bathrooms','stories']]

# Putting feature variable to y
y = Housing_multi[['parking']]

# %%
# random_state is the seed used by the random number generator It can be any integer
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7 , random_state=100)

# %%
X_train
# Out:
#         price   area  bedrooms  bathrooms  stories
# 359   3710000   3600         3          1        1
# 19    8855000   6420         3          2        2
# 159   5460000   3150         3          2        1
# 35    8080940   7000         3          2        4
# 28    8400000   7950         5          2        2
# 267   4403000   4920         3          1        2
# 263   4410000   3968         3          1        2
# 433   3290000   3480         4          1        2
# 217   4830000   6862         3          1        2
# 154   5530000   3650         3          2        2
# 534   2100000   3000         4          1        2
# 96    6300000   9000         3          1        1
# 33    8190000   5960         3          3        2
# 477   2940000   4960         2          1        1
# 129   5873000  11460         3          1        3
# 401   3500000   9500         3          1        2
# 240   4585000   3840         3          1        2
# ...

# %% [markdown]
# ##  Step-4 :- Performing Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
# Representing the Linear Regression as lr(Creating LinearRegression Object )
lm = LinearRegression()

# %%
#fits the model to the training data 
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ## Step-5:- Model Evaluation

# %%
# print the intercept 
print(lm.intercept_)
# Out:
# [-0.30380599]

# %%
coeff_df = pd.DataFrame(lm.coef_)
coeff_df
# Out:
#               0         1         2         3         4
# 0  1.328114e-07  0.000093  0.080692 -0.050778 -0.137577

# %% [markdown]
# ## Step6 :- Predictions

# %%
# Making predictions using the model 
y_pred = lm.predict(X_test)
y_pred
# Out:
# array([[0.46478209],
#        [1.09538031],
#        [1.40160282],
#        [0.71108513],
#        [0.73507637],
#        [0.77431334],
#        [1.38430717],
#        [0.94735756],
#        [0.6638081 ],
#        [1.14798815],
#        [0.68150157],
#        [1.16288443],
#        [0.21737545],
#        [1.98911774],
#        [0.83343571],
#        [0.66142503],
#        [1.96161401],
#        [0.70505842],
#        [1.26700245],
#        [0.82714654],
#        [0.44800658],
#        [0.74159027],
#        [0.50028869],
#        [0.60804768],
#        [0.49451175],
#        [0.31759439],
#        [0.70719718],
#        [1.03308897],
#        [0.8945218 ],
#        [1.45927036],
#        [0.07081005],
#        [0.4712552 ],
#        [0.55694712],
#        [0.2593846 ],
#        [0.95276808],
#        [0.63857722],
#        [0.45767994],
#        [0.48984042],
#        [0.4946871 ],
#        [0.56282206],
#        [0.66760988],
#        [0.55194093],
#        [1.13699524],
# ...

# %% [markdown]
# ##  Step-7:- Calculating the Error Terms

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
r_squared= r2_score(y_test, y_pred)

# %%
print('Mean_squared-error:', mse)
print('r_square_value :',r_squared)
# Out:
# Mean_squared-error: 0.6192784888745965
# r_square_value : 0.17294233890604582

# %%
import statsmodels.api as sm
X_train_sm = X_train
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X_train_sm = sm.add_constant(X_train_sm)
# create a fitted model in one line
lm_1 = sm.OLS(y_train,X_train_sm).fit()

# print the coefficients
lm_1.params
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# const       -3.038060e-01
# price        1.328114e-07
# area         9.294252e-05
# bedrooms     8.069229e-02
# bathrooms   -5.077775e-02
# stories     -1.375771e-01
# dtype: float64

# %%
print(lm_1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                parking   R-squared:                       0.184
# Model:                            OLS   Adj. R-squared:                  0.173
# Method:                 Least Squares   F-statistic:                     16.91
# Date:                Thu, 07 Jan 2021   Prob (F-statistic):           4.42e-15
# Time:                        16:32:03   Log-Likelihood:                -442.94
# No. Observations:                 381   AIC:                             897.9
# Df Residuals:                     375   BIC:                             921.5
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.3038      0.191     -1.595      0.112      -0.678       0.071
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.figure(figsize = (5,5))
sns.heatmap(Housing_multi.corr(),annot = True)

# %% [markdown]
# ## Step 8 Implementing the results and running the model again

# %%
# Removing Bathrooms from our dataset
X_train_new = X_train[['price','area','bedrooms','stories']]
X_test_new = X_test[['price','area','bedrooms','stories']]

# %%
# Model building
lm.fit(X_train_new,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Making predictions
y_pred_new = lm.predict(X_test_new)

# %%
#Actual vs Predicted
c = [i for i in range(0,164,1)]
fig = plt.figure()
plt.plot(c,y_test, color="blue", linewidth=2.5, linestyle="-")
plt.plot(c,y_pred, color="red",  linewidth=2.5, linestyle="-")
fig.suptitle('Actual and Predicted', fontsize=20)              # Plot heading 
plt.xlabel('index', fontsize=18)                               # X-label
plt.ylabel('parking', fontsize=16)                             # Y-label
# Out:
# Text(0, 0.5, 'parking')

# %%
# Error terms
c = [i for i in range(0,164,1)]
fig = plt.figure()
plt.plot(c,y_test-y_pred, color="blue", linewidth=2.5, linestyle="-")
fig.suptitle('Error Terms', fontsize=20)              # Plot heading 
plt.xlabel('Index', fontsize=18)                      # X-label
plt.ylabel('ytest-ypred', fontsize=16)
# Out:
# Text(0, 0.5, 'ytest-ypred')

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred_new)
r_squared = r2_score(y_test, y_pred_new)

# %%
print('Mean_Squared_Error :' ,mse)
print('r_square_value :',r_squared)
# Out:
# Mean_Squared_Error : 0.6172967616707831
# r_square_value : 0.1755889715528388

# %%
X_train_final = X_train_new
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X_train_final = sm.add_constant(X_train_final)
# create a fitted model in one line
lm_final = sm.OLS(y_train,X_train_final).fit()

print(lm_final.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                parking   R-squared:                       0.183
# Model:                            OLS   Adj. R-squared:                  0.175
# Method:                 Least Squares   F-statistic:                     21.12
# Date:                Thu, 07 Jan 2021   Prob (F-statistic):           1.01e-15
# Time:                        17:07:32   Log-Likelihood:                -443.07
# No. Observations:                 381   AIC:                             896.1
# Df Residuals:                     376   BIC:                             915.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.3263      0.185     -1.765      0.078      -0.690       0.037
# ...

# %% [markdown]
# #  Model Refinement using RFE

# %%
from sklearn.feature_selection import RFE

# %%
rfe = RFE(lm, 2)

# %%
rfe = rfe.fit(X_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
print(rfe.support_)
print(rfe.ranking_)
# Out:
# [False False  True  True False]
# [4 3 1 1 2]

# %% [markdown]
# ##  Simple Linear Regression : Bathrooms(X) and Parking(y)

# %%
import pandas as pd
import numpy as np

# Importing dataset
Housing_multi = pd.read_csv('Housing.csv')

x_bathroom = Housing_multi['bathrooms']

y_bathroom = Housing_multi['parking']

# Data Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_bathroom, y_bathroom, 
                                                    train_size=0.7 , 
                                                    random_state=110)

# Required only in the case of simple linear regression
X_train = X_train[:,np.newaxis]
X_test = X_test[:,np.newaxis]

# Linear regression from sklearn
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

# Fitting the model
lm.fit(X_train,y_train)

# Making predictions
y_pred = lm.predict(X_test)

# Importing mean square error and r square from sklearn library.
from sklearn.metrics import mean_squared_error, r2_score

# Computing mean square error and R square value
mse = mean_squared_error(y_test, y_pred)
r_squared = r2_score(y_test, y_pred)

# Printing mean square error and R square value
print('Mean_Squared_Error :' ,mse)
print('r_square_value :',r_squared)
# Out:
# Mean_Squared_Error : 0.6993469768390463
# r_square_value : -0.006508791152771254
